# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import sys
import requests
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor

# %%
url = 'https://anapioficeandfire.com/api/characters/2138'
url = 'https://anapioficeandfire.com/api/characters/1'

response = requests.get(url).json()
print(response)
# Out:
# {'url': 'https://www.anapioficeandfire.com/api/characters/1', 'name': '', 'gender': 'Female', 'culture': 'Braavosi', 'born': '', 'died': '', 'titles': [''], 'aliases': ['The Daughter of the Dusk'], 'father': '', 'mother': '', 'spouse': '', 'allegiances': [], 'books': ['https://www.anapioficeandfire.com/api/books/5'], 'povBooks': [], 'tvSeries': [''], 'playedBy': ['']}

# %%
df = pd.DataFrame(columns = ['Name','Gender','Aliases','playedBy']) 
df
# Out:
# Empty DataFrame
# Columns: [Name, Gender, Aliases, playedBy]
# Index: []

# %%
# %%time
for i in list(range(15,250)):
    tempURL = 'https://anapioficeandfire.com/api/characters/' + str(i)
    response = requests.get(tempURL).json()
    temp = dict()
    temp = {'Name':response['name'],'Gender':response['gender'], 'Aliases':response['aliases'], 'playedBy':response['playedBy']}
    df = df.append(temp,ignore_index=True)
df.to_csv('Ice and Fire.csv')
# Out:
# CPU times: user 5.75 s, sys: 249 ms, total: 6 s
# Wall time: 25.5 s

# %%
df
# Out:
#                     Name  Gender  \
# 0            High Septon     NaN
# 1        Margaery Tyrell     NaN
# 2               Melicent     NaN
# 3               Meribald     NaN
# 4                 Moelle     NaN
# 5            High Septon    Male
# 6        Margaery Tyrell  Female
# 7               Melicent  Female
# 8               Meribald    Male
# 9                 Moelle  Female
# 10           High Septon    Male
# 11       Margaery Tyrell  Female
# 12              Melicent  Female
# 13              Meribald    Male
# 14                Moelle  Female
# 15               Mordane  Female
# 16             Nysterica  Female
# 17               Ollidor    Male
# 18                Osmynd    Male
# 19               Raynard    Male
# 20               Scolera  Female
# 21               Torbert    Male
# 22       Tywin Lannister    Male
# 23                Unella  Female
# 24      Abelar Hightower    Male
# 25            Addam Frey    Male
# 26        Addam Marbrand    Male
# 27          Addam Osgrey    Male
# 28        Addam Velaryon    Male
# 29          Addison Hill    Male
# ..                   ...     ...
# 215          Bryce Caron    Male
# 216          Bryen Caron    Male
# 217        Bryen Farring    Male
# 218        Brynden Tully    Male
# 219        Buford Bulwer    Male
# 220     Burton Crakehall    Male
# 221      Calla Blackfyre  Female
# 222   Carellen Smallwood  Female
# 223     Carolei Waynwood  Female
# 224         Casper Wylde    Male
# 225    Cassana Estermont  Female
# 226       Cassella Vaith  Female
# 227        Catelyn Stark  Female
# 228         Cedric Payne    Male
# 229         Cedrik Storm    Male
# 230    Cerenna Lannister  Female
# 231         Cerissa Brax  Female
# 232          Cersei Frey  Female
# 233     Cersei Lannister  Female
# 234     Ceryse Hightower  Female
# 235    Clarence Charlton    Male
# 236       Clarence Crabb    Male
# 237    Clarent Crakehall    Male
# 238        Clayton Suggs    Male
# 239        Clement Crabb    Male
# 240        Clement Piper    Male
# 241      Cletus Yronwood    Male
# 242          Cley Cerwyn    Male
# 243      Cleyton Caswell    Male
# 244  Colen of Greenpools    Male
#
#                                                Aliases             playedBy
# 0                                                  NaN                  NaN
# 1                                                  NaN                  NaN
# 2                                                  NaN                  NaN
# 3                                                  NaN                  NaN
# 4                                                  NaN                  NaN
# 5                                   [The High Sparrow]     [Jonathan Pryce]
# 6    [The Little Queen, The Little Rose, Maid Marga...     [Natalie Dormer]
# 7                                                   []                   []
# 8                                                   []                   []
# 9                                                   []                   []
# 10                                  [The High Sparrow]     [Jonathan Pryce]
# 11   [The Little Queen, The Little Rose, Maid Marga...     [Natalie Dormer]
# 12                                                  []                   []
# 13                                                  []                   []
# 14                                                  []                   []
# 15                                                  []        [Susan Brown]
# 16                                                  []                   []
# 17                                                  []                   []
# 18                                                  []                   []
# 19                                                  []                   []
# 20                                                  []                   []
# 21                                                  []                   []
# 22   [The Lion of Lannister, The Old Lion, The Grea...      [Charles Dance]
# 23                                                  []  [Hannah Waddingham]
# 24                                                  []                   []
# 25                                                  []                   []
# 26                                                  []          [B.J. Hogg]
# 27                                                  []                   []
# 28                                     [Addam of Hull]                   []
# 29                          [The Bastard of Cornfield]                   []
# ..                                                 ...                  ...
# 215                                 [Bryce the Orange]                   []
# 216                                                 []                   []
# 217                                                 []                   []
# 218  [Blackfish, Ser Brynden the Blackfish, Brynden...      [Clive Russell]
# 219                                       [The Old Ox]                   []
# 220                                                 []                   []
# 221                                                 []                   []
# 222                                                 []                   []
# 223                                                 []                   []
# 224                                                 []                   []
# 225                                                 []                   []
# 226                                                 []                   []
# 227  [Catelyn Tully, Lady Stoneheart, The Silent Si...   [Michelle Fairley]
# 228                                                 []                   []
# 229                        [the Bastard of Bronzegate]                   []
# 230                                                 []                   []
# 231                                                 []                   []
# 232                                   [the Little Bee]                   []
# 233                     [Brotherfuckerthe bitch queen]        [Lena Headey]
# 234                                                 []                   []
# 235                                                 []                   []
# 236                               [Clarence the Short]                   []
# 237                                                 []                   []
# 238                                                 []                   []
# 239                                                 []                   []
# 240                                                 []                   []
# 241                                                 []                   []
# 242                                                 []                   []
# 243                                                 []                   []
# 244                                                 []                   []
#
# [245 rows x 4 columns]

# %%
print(df)
# Out:
#                     Name  Gender  \
# 0            High Septon     NaN
# 1        Margaery Tyrell     NaN
# 2               Melicent     NaN
# 3               Meribald     NaN
# 4                 Moelle     NaN
# 5            High Septon    Male
# 6        Margaery Tyrell  Female
# 7               Melicent  Female
# 8               Meribald    Male
# 9                 Moelle  Female
# 10           High Septon    Male
# 11       Margaery Tyrell  Female
# 12              Melicent  Female
# 13              Meribald    Male
# 14                Moelle  Female
# 15               Mordane  Female
# 16             Nysterica  Female
# 17               Ollidor    Male
# 18                Osmynd    Male
# 19               Raynard    Male
# 20               Scolera  Female
# 21               Torbert    Male
# 22       Tywin Lannister    Male
# 23                Unella  Female
# 24      Abelar Hightower    Male
# 25            Addam Frey    Male
# 26        Addam Marbrand    Male
# 27          Addam Osgrey    Male
# 28        Addam Velaryon    Male
# 29          Addison Hill    Male
# ..                   ...     ...
# 450          Bryce Caron    Male
# 451          Bryen Caron    Male
# 452        Bryen Farring    Male
# 453        Brynden Tully    Male
# 454        Buford Bulwer    Male
# 455     Burton Crakehall    Male
# 456      Calla Blackfyre  Female
# 457   Carellen Smallwood  Female
# 458     Carolei Waynwood  Female
# 459         Casper Wylde    Male
# 460    Cassana Estermont  Female
# 461       Cassella Vaith  Female
# 462        Catelyn Stark  Female
# 463         Cedric Payne    Male
# 464         Cedrik Storm    Male
# 465    Cerenna Lannister  Female
# 466         Cerissa Brax  Female
# 467          Cersei Frey  Female
# 468     Cersei Lannister  Female
# 469     Ceryse Hightower  Female
# 470    Clarence Charlton    Male
# 471       Clarence Crabb    Male
# 472    Clarent Crakehall    Male
# 473        Clayton Suggs    Male
# 474        Clement Crabb    Male
# 475        Clement Piper    Male
# 476      Cletus Yronwood    Male
# 477          Cley Cerwyn    Male
# 478      Cleyton Caswell    Male
# 479  Colen of Greenpools    Male
#
#                                                Aliases             playedBy
# 0                                                  NaN                  NaN
# 1                                                  NaN                  NaN
# 2                                                  NaN                  NaN
# 3                                                  NaN                  NaN
# 4                                                  NaN                  NaN
# 5                                   [The High Sparrow]     [Jonathan Pryce]
# 6    [The Little Queen, The Little Rose, Maid Marga...     [Natalie Dormer]
# 7                                                   []                   []
# 8                                                   []                   []
# 9                                                   []                   []
# 10                                  [The High Sparrow]     [Jonathan Pryce]
# 11   [The Little Queen, The Little Rose, Maid Marga...     [Natalie Dormer]
# 12                                                  []                   []
# 13                                                  []                   []
# 14                                                  []                   []
# 15                                                  []        [Susan Brown]
# 16                                                  []                   []
# 17                                                  []                   []
# 18                                                  []                   []
# 19                                                  []                   []
# 20                                                  []                   []
# 21                                                  []                   []
# 22   [The Lion of Lannister, The Old Lion, The Grea...      [Charles Dance]
# 23                                                  []  [Hannah Waddingham]
# 24                                                  []                   []
# 25                                                  []                   []
# 26                                                  []          [B.J. Hogg]
# 27                                                  []                   []
# 28                                     [Addam of Hull]                   []
# 29                          [The Bastard of Cornfield]                   []
# ..                                                 ...                  ...
# 450                                 [Bryce the Orange]                   []
# 451                                                 []                   []
# 452                                                 []                   []
# 453  [Blackfish, Ser Brynden the Blackfish, Brynden...      [Clive Russell]
# 454                                       [The Old Ox]                   []
# 455                                                 []                   []
# 456                                                 []                   []
# 457                                                 []                   []
# 458                                                 []                   []
# 459                                                 []                   []
# 460                                                 []                   []
# 461                                                 []                   []
# 462  [Catelyn Tully, Lady Stoneheart, The Silent Si...   [Michelle Fairley]
# 463                                                 []                   []
# 464                        [the Bastard of Bronzegate]                   []
# 465                                                 []                   []
# 466                                                 []                   []
# 467                                   [the Little Bee]                   []
# 468                     [Brotherfuckerthe bitch queen]        [Lena Headey]
# 469                                                 []                   []
# 470                                                 []                   []
# 471                               [Clarence the Short]                   []
# 472                                                 []                   []
# 473                                                 []                   []
# 474                                                 []                   []
# 475                                                 []                   []
# 476                                                 []                   []
# 477                                                 []                   []
# 478                                                 []                   []
# 479                                                 []                   []
#
# [480 rows x 4 columns]

# %%
#-----------------------------------source1-----------------------------------

# %%
# sys.argv[1] is the content you typed in the command line
if sys.argv[1] == 'source1':
    if sys.argv[2] == 'remote':
        print('\n')
        print('*** Outputing data source 1 *** ')
        print('\n')
        url = 'https://anapioficeandfire.com/api/characters/'
        print('Official JSON API providing information for the Ice and Fire .\n')
        print('we are grabbing the name of each charactor, his gender, his aliases and playedBy. \n')
        print('URL:')
        print(url)
        print('\n')
        print('Sample Output\n')
        df = pd.DataFrame(columns = ['Name','Gender','Aliases','playedBy']) 
        for i in list(range(15,150)):
            tempURL = 'https://anapioficeandfire.com/api/characters/' + str(i)
            response = requests.get(tempURL).json()
            temp = dict()
            temp = {'Name':response['name'],'Gender':response['gender'], 'Aliases':response['aliases'], 'playedBy':response['playedBy']}
            print(temp)
            df = df.append(temp,ignore_index=True)
        df.to_csv('Ice and Fire.csv')
    if sys.argv[2] == 'local':
        myData = pd.read_csv('Ice and Fire.csv')
        print(myData)

# %%
#-----------------------------------source2-----------------------------------

# %%
# sys.argv[1] is the content you typed in the command line
if sys.argv[1] == 'source2':
    if sys.argv[2] == 'remote':
        print('\n')
        print('*** Outputing data source 2 *** ')
        print('\n')
        url = 'https://book.douban.com/'
        print('The data contains the most popular books nowadays in the China largest reading website.\n')
        print('we are grabbing the name and the detail description link of the book. \n')
        print('URL:')
        print(url)
        print('\n')
        print('Sample Output\n')
        url = 'https://book.douban.com/'
        html = urllib.request.urlopen(url).read()
        soup = BeautifulSoup(html, 'lxml')

        temp2 = soup.find_all('div', class_="title")

        name1 = temp2[1].get_text()
        name1 = name1[1:len(name1)-1]
        link1 = temp2[1].find('a').get('href', None)
        print(name1, link1)

        name1 = temp2[2].get_text()
        name1 = name1[2:len(name1)-1]
        link1 = temp2[2].find('a').get('href', None)
        print(name1, link1)

        name1 = temp2[3].get_text()
        name1 = name1[3:len(name1)-1]
        link1 = temp2[2].find('a').get('href', None)
        print(name1, link1)
    if sys.argv[2] == 'local':
        myData = pd.read_csv('Ice and Fire.csv')
        print(myData)

# %%
# Out:
# 绩效使能：超越OKR https://book.douban.com/subject/30488568/?icn=index-latestbook-subject
# 身符1 https://book.douban.com/subject/30389739/?icn=index-latestbook-subject
# 与边缘 https://book.douban.com/subject/30389739/?icn=index-latestbook-subject

# %%
#-----------------------------------source3-----------------------------------

# %%
# sys.argv[1] is the content you typed in the command line
if sys.argv[1] == 'source3':
    if sys.argv[2] == 'remote':
        print('\n')
        print('*** Outputing data source 3 *** ')
        print('\n')
        url = 'https://www.imdb.com/movies-in-theaters/?ref_=nv_tp_inth_1'
        print('It contains the movie imformation.\n')
        print('we are grabbing the Movie Synopsis. \n')
        print('URL:')
        print(url)
        print('\n')
        print('Sample Output\n')
        url = 'https://www.imdb.com/movies-in-theaters/?ref_=nv_tp_inth_1'
        html = urllib.request.urlopen(url).read()
        soup = BeautifulSoup(html, 'lxml')
        temp2 = soup.find_all('td', class_="overview-top")

        print(temp2[0].find_all('div', class_ = 'outline')[0].get_text()[3:])
        print(temp2[1].find_all('div', class_ = 'outline')[0].get_text()[3:])
        print(temp2[2].find_all('div', class_ = 'outline')[0].get_text()[3:])
    if sys.argv[2] == 'local':
        myData = pd.read_csv('Ice and Fire.csv')
        print(myData)

# %%
# Out:
#   Ignoring the eerie warning of a troubled mother suspected of child endangerment, a social worker and her own small kids are soon drawn into a frightening supernatural realm.
#   The story of Steve, an Adélie penguin, on a quest to find a life partner and start a family. When Steve meets with Wuzzo the emperor penguin they become friends. But nothing comes easy in the icy Antarctic.
#   Drama set in the 1940s during the partition of India.

# %%
temp2[0].find_all('div', class_ = 'outline')
# Out:
# [<div class="outline">
#      Ignoring the eerie warning of a troubled mother suspected of child endangerment, a social worker and her own small kids are soon drawn into a frightening supernatural realm.                    </div>]

# %%
type(temp2[0].find_all('div', class_ = 'outline'))
# Out:
# bs4.element.ResultSet

# %%
print(temp2[0].find_all('div', class_ = 'outline'))
# Out:
# [<div class="outline">
#     Ignoring the eerie warning of a troubled mother suspected of child endangerment, a social worker and her own small kids are soon drawn into a frightening supernatural realm.                    </div>]

# %%
temp2[0].find_all('div', class_ = 'outline')[0].get_text()[3:]
# Out:
# '  Ignoring the eerie warning of a troubled mother suspected of child endangerment, a social worker and her own small kids are soon drawn into a frightening supernatural realm.                    '
